# %%
import numpy as np
from maf import MAFMap, Agent,Grid
import matplotlib.pyplot as plt
import json
from matplotlib import colors
import time
# %load_ext autoreload
# %autoreload 2

# %%
g=Grid('new_map.json')
grid=g.return_grid()
m=MAFMap(grid,8,0)
agents=[]
n=20
for i in range(n):
    agents.append(Agent(0,0,2,i%8,m))

# %%
np.sum(grid==-1)
# Out:
# 4044

# %%
np.sum(grid==-2)
# Out:
# 0

# %%
t1=time.time()
agent_mode=[0]*n
moves=0
while m.covered()<.95 or moves<250000:
    agents[i].next()
    if agents[i].mode!=agent_mode[i]:
        print(i,agents[i].mode,agents[i].sc,moves,m.covered())
        agent_mode[i]=agents[i].mode
    i+=1
    i=i%n
    if i==0:
        moves+=1
        if moves%50000==0:
            print(moves,m.covered(),m.poi_covered(), end= ' ')
            print('elapsed time: {}'.format(time.time()-t1))
t2=time.time()
print(t2-t1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-1d4d3c52f2b7> in <module>
#      12         moves+=1
#      13         if moves%50000==0:
# ---> 14             print(moves,m.covered(),m.poi_covered(), end= ' ')
#      15             print('elapsed time: {}'.format(time.time()-t1))
#      16 t2=time.time()
#
# ~/Documents/maf/maf.py in poi_covered(self)
#     116         returns fraction of points of interest covered
#     117         '''
# --> 118         return self.explored_poi/self.num_poi
#     119
#     120
#
# AttributeError: 'MAFMap' object has no attribute 'explored_poi'

# %%
print(moves)
# Out:
# 2086

# %%
plt.figure(figsize=(25,25))
mask = np.ma.masked_greater(grid,1)
#plt.imshow(grid)
plt.imshow(mask,cmap='rainbow')
#plt.imshow(grid)

# %%
np.sum(grid==-1)
# Out:
# 4044

# %%
while m.covered()<.3:
    agents[i%n].next()
    i+=1
    i=i%n

# %%
plt.figure(figsize=(25,25))
mask = np.ma.masked_greater(grid,1)
#plt.imshow(grid)
plt.imshow(mask)
#plt.imshow(grid)

# %%
while m.covered()<.8:
    agents[i%n].next()
    i+=1
    i=i%n
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-bd3d7320e3d1> in <module>
#       1 while m.covered()<.8:
# ----> 2     agents[i%n].next()
#       3     i+=1
#       4     i=i%n
#
# ~/Documents/maf/maf.py in next(self)
#     279         #return mode
#     280         elif self.mode==1:
# --> 281             values,directions,action=self.map.get_explored(self.x,self.y)
#     282             self.d=directions[0]
#     283             self.move(False)
#
# ~/Documents/maf/maf.py in get_explored(self, x, y)
#     165                     if (xdir!=0 or ydir!=0):
#     166                         #look at only explored cells
# --> 167                         if value!=0 and value!=-1 and value!=None:
#     168                             explored_directions.append(d)
#     169                             explored.append(value)
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(25,25))
mask = np.ma.masked_greater(grid,1)
#plt.imshow(grid)
plt.imshow(mask)
#plt.imshow(grid)

# %%
m.covered()
# Out:
# 0.736778122916294

# %%
for i in range(n):
    print(agents[i].sc)
# Out:
# 193052
# 2837564
# 87139
# 71449
# 252500
# 179685
# 1255845
# 210320
# 36330
# 734732
